# %%
# %matplotlib inline
import os, sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
data=pd.read_csv("bike_count.csv",index_col="Date",parse_dates=True)

# %%
data.columns=['West','East']

# %%
data.plot()

# %%
weekend=np.where(data.index.dayofweek<4,'yes','no')
by_time=data.groupby([weekend,data.index.time]).mean()
weekend
# Out:
# array(['yes', 'yes', 'yes', ..., 'no', 'no', 'no'],
#       dtype='<U3')

# %%
fig,ax=plt.subplots(1,2,figsize=(14,5))
by_time.loc['Weekday'].plot(ax=ax[0],title='Weekdays',
                           xticks=hourly_ticks,style=['-',"--",':'])
by_time.loc['Weekend'].plot(ax=ax[1],title='Weekends',
                           xticks=hourly_ticks,style=['-','--',':'])

# %%
data.index.dayofweek
# Out:
# Int64Index([2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#             ...
#             4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#            dtype='int64', name='Date', length=41568)
